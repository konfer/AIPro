# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
# %matplotlib inline

# %%
# Sklearn common imports!
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import StratifiedShuffleSplit
seed = 123

# %%
# stat import!
from statsmodels.distributions.empirical_distribution import ECDF

# %%
# Sklearn text-Feature-Engineer  imports!
from sklearn.linear_model import Lasso, LassoCV

# %%
# Sklearn Feature-Engineer  imports!
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import Imputer
from sklearn.pipeline import Pipeline

# %%
# Sklearn model-ensemble!
from sklearn.ensemble import RandomForestRegressor

# %%
autoData = pd.read_csv(r"autoPredict/Auto-Data.csv", na_values = '?')

# %%
autoData.shape
# Out:
# (205, 26)

# %%
autoData.head(10)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
# 5          2                NaN         audi       gas        std
# 6          1              158.0         audi       gas        std
# 7          1                NaN         audi       gas        std
# 8          1              158.0         audi       gas      turbo
# 9          0                NaN         audi       gas      turbo
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base   ...     \
# 0          two  convertible          rwd           front        88.6   ...
# 1          two  convertible          rwd           front        88.6   ...
# ...

# %%
autoData.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
autoData.describe().T
# Out:
#                    count          mean          std      min      25%  \
# symboling          205.0      0.834146     1.245307    -2.00     0.00
# normalized-losses  164.0    122.000000    35.442168    65.00    94.00
# wheel-base         205.0     98.756585     6.021776    86.60    94.50
# length             205.0    174.049268    12.337289   141.10   166.30
# width              205.0     65.907805     2.145204    60.30    64.10
# height             205.0     53.724878     2.443522    47.80    52.00
# curb-weight        205.0   2555.565854   520.680204  1488.00  2145.00
# engine-size        205.0    126.907317    41.642693    61.00    97.00
# bore               201.0      3.329751     0.273539     2.54     3.15
# stroke             201.0      3.255423     0.316717     2.07     3.11
# compression-ratio  205.0     10.142537     3.972040     7.00     8.60
# horsepower         203.0    104.256158    39.714369    48.00    70.00
# ...

# %%
autoData.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
autoData.head(20)
# Out:
#     symboling  normalized-losses         make fuel-type aspiration  \
# 0           3                NaN  alfa-romero       gas        std
# 1           3                NaN  alfa-romero       gas        std
# 2           1                NaN  alfa-romero       gas        std
# 3           2              164.0         audi       gas        std
# 4           2              164.0         audi       gas        std
# 5           2                NaN         audi       gas        std
# 6           1              158.0         audi       gas        std
# 7           1                NaN         audi       gas        std
# 8           1              158.0         audi       gas      turbo
# 9           0                NaN         audi       gas      turbo
# 10          2              192.0          bmw       gas        std
# 11          0              192.0          bmw       gas        std
# 12          0              188.0          bmw       gas        std
# ...

# %%
autoData.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
msno.matrix(autoData)

# %%
autoData.loc[pd.isnull(autoData.loc[:, 'normalized-losses'])].head(20)
# Out:
#     symboling  normalized-losses           make fuel-type aspiration  \
# 0           3                NaN    alfa-romero       gas        std
# 1           3                NaN    alfa-romero       gas        std
# 2           1                NaN    alfa-romero       gas        std
# 5           2                NaN           audi       gas        std
# 7           1                NaN           audi       gas        std
# 9           0                NaN           audi       gas      turbo
# 14          1                NaN            bmw       gas        std
# 15          0                NaN            bmw       gas        std
# 16          0                NaN            bmw       gas        std
# 17          0                NaN            bmw       gas        std
# 43          0                NaN          isuzu       gas        std
# 44          1                NaN          isuzu       gas        std
# 45          0                NaN          isuzu       gas        std
# ...

# %%
cdf = ECDF(autoData.loc[:, 'normalized-losses'])

# %%
plt.plot(cdf.x, cdf.y, label = "statmodels", color = 'r');

# %%
cdf(200)
# Out:
# 0.7902439024390244

# %%
cdf(125)
# Out:
# 0.47317073170731705

# %%
plt.plot(autoData.loc[:, 'normalized-losses'].dropna(),color = 'b' )

# %%
plt.hist(autoData.loc[:, 'normalized-losses'].dropna(), 
         bins = int(np.sqrt(len(autoData.loc[:, 'normalized-losses']))),
         color = 'b');

# %%
int(np.sqrt(len(autoData['normalized-losses'])))
# Out:
# 14

# %%
corr_matrix = autoData.corr()

# %%
corr_matrix
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.528667   -0.531954 -0.357612
# normalized-losses   0.528667           1.000000   -0.074362  0.023220
# wheel-base         -0.531954          -0.074362    1.000000  0.874587
# length             -0.357612           0.023220    0.874587  1.000000
# width              -0.232919           0.105073    0.795144  0.841118
# height             -0.541038          -0.432335    0.589435  0.491029
# curb-weight        -0.227691           0.119893    0.776386  0.877728
# engine-size        -0.105790           0.167365    0.569329  0.683360
# bore               -0.134205          -0.036167    0.490378  0.607480
# stroke             -0.008965           0.065627    0.161477  0.129739
# compression-ratio  -0.178515          -0.132654    0.249786  0.158414
# horsepower          0.071622           0.295772    0.352297  0.555003
# ...

# %%
sns.heatmap(corr_matrix)

# %%
corr_matrix.loc[:, 'normalized-losses'].sort_values(ascending = False)
# Out:
# normalized-losses    1.000000
# symboling            0.528667
# horsepower           0.295772
# peak-rpm             0.264597
# price                0.203254
# engine-size          0.167365
# curb-weight          0.119893
# width                0.105073
# stroke               0.065627
# length               0.023220
# bore                -0.036167
# wheel-base          -0.074362
# compression-ratio   -0.132654
# highway-mpg         -0.210768
# city-mpg            -0.258502
# height              -0.432335
# Name: normalized-losses, dtype: float64

# %%
autoData.loc[:, 'normalized-losses'] = autoData.groupby('symboling')["normalized-losses"].transform(lambda x: x.fillna(x.mean()))

# %%
autoData.head(20)
# Out:
#     symboling  normalized-losses         make fuel-type aspiration  \
# 0           3         168.647059  alfa-romero       gas        std
# 1           3         168.647059  alfa-romero       gas        std
# 2           1         128.574468  alfa-romero       gas        std
# 3           2         164.000000         audi       gas        std
# 4           2         164.000000         audi       gas        std
# 5           2         125.689655         audi       gas        std
# 6           1         158.000000         audi       gas        std
# 7           1         128.574468         audi       gas        std
# 8           1         158.000000         audi       gas      turbo
# 9           0         113.166667         audi       gas      turbo
# 10          2         192.000000          bmw       gas        std
# 11          0         192.000000          bmw       gas        std
# 12          0         188.000000          bmw       gas        std
# ...

# %%
autoData.dropna(subset = ['price', 'bore', 'stroke', 'peak-rpm', 'horsepower', 'num-of-doors'], 
                inplace = True)

# %%
autoData.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
corr_matrix = corr_matrix.stack()

# %%
corr_matrix
# Out:
# symboling          symboling            1.000000
#                    normalized-losses    0.528667
#                    wheel-base          -0.531954
#                    length              -0.357612
#                    width               -0.232919
#                    height              -0.541038
#                    curb-weight         -0.227691
#                    engine-size         -0.105790
#                    bore                -0.134205
#                    stroke              -0.008965
#                    compression-ratio   -0.178515
#                    horsepower           0.071622
#                    peak-rpm             0.274573
#                    city-mpg            -0.035823
#                    highway-mpg          0.034606
#                    price               -0.082391
# normalized-losses  symboling            0.528667
#                    normalized-losses    1.000000
#                    wheel-base          -0.074362
# ...

# %%
corr_matrix = corr_matrix.reindex(corr_matrix.abs().sort_values(ascending=False).index).reset_index()

# %%
corr_matrix
# Out:
#                level_0            level_1         0
# 0                price              price  1.000000
# 1          highway-mpg        highway-mpg  1.000000
# 2    normalized-losses  normalized-losses  1.000000
# 3           wheel-base         wheel-base  1.000000
# 4               length             length  1.000000
# 5                width              width  1.000000
# 6               height             height  1.000000
# 7          curb-weight        curb-weight  1.000000
# 8          engine-size        engine-size  1.000000
# 9                 bore               bore  1.000000
# 10              stroke             stroke  1.000000
# 11   compression-ratio  compression-ratio  1.000000
# 12          horsepower         horsepower  1.000000
# 13            peak-rpm           peak-rpm  1.000000
# 14            city-mpg           city-mpg  1.000000
# 15           symboling          symboling  1.000000
# 16            city-mpg        highway-mpg  0.971337
# ...

# %%
sns.pairplot(autoData)

# %%
autoData['volume'] = autoData.length * autoData.width * autoData.height

# %%
autoData.drop(['width', 'length', 'height', 
           'curb-weight', 'city-mpg'], 
          axis = 1, # 1 for columns
          inplace = True)

# %%
autoData.shape
# Out:
# (193, 22)

# %%
autoData.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'engine-type', 'num-of-cylinders', 'engine-size',
#        'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower',
#        'peak-rpm', 'highway-mpg', 'price', 'volume'],
#       dtype='object')

# %%
regressors = [x for x in autoData.columns if x not in ['price']]

# %%
regressors
# Out:
# ['symboling',
#  'normalized-losses',
#  'make',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'wheel-base',
#  'engine-type',
#  'num-of-cylinders',
#  'engine-size',
#  'fuel-system',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'highway-mpg',
#  'volume']

# %%
regressorsByDrop = autoData.columns.drop("price")

# %%
regressorsByDrop
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'engine-type', 'num-of-cylinders', 'engine-size',
#        'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower',
#        'peak-rpm', 'highway-mpg', 'volume'],
#       dtype='object')
