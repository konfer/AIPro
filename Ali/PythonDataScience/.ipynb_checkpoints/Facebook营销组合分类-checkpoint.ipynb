# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
# Out:
# d:\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def load_data(path):
    """加载数据集，并对数据集进行处理。
    
    Parameters
    -----
    path : str
        数据集的路径。
        
    Returns
    -----
    (X, y) : tuple
        特征矩阵X与对应的标签y。
    """
    
    # 加载数据集，注意数据集中没有标题行，需要将header的值设置为None。
    data = pd.read_csv(path, header=None)
    # 将加载的数据集分为特征X与标签y。
    X, y = data.iloc[:, :-1], data.iloc[:, -1]
    # 对特征矩阵X进行编码。
    lb = LabelEncoder()
    X = X.apply(lambda col: lb.fit_transform(col))
    # 进行one-hot编码
    ohe = OneHotEncoder()
    X = pd.DataFrame(ohe.fit_transform(X).toarray())
    # tensorflow不支持数值列，需要转换。
    X.columns = X.columns.map(lambda x: f"c{x}")
    return X, y

def train_input_fn(features, labels):
    """定义训练函数，用于训练使用。
    
    Parameters
    -----
    features : 类数组类型。 形状：[样本数量， 特征数量]
        用于训练的特征矩阵。
    labels : 类数组类型。形状为：[样本数量]
        每个样本对应的标签。（分类）
        
    Returns
    -----
    dataset : tf.data.Dataset
        数据集。
    """
    
    # 创建数据集
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))
    # 对数据集进行洗牌，重复与分批处理。
    dataset = dataset.shuffle(10000, seed=0).repeat(10).batch(50)
    return dataset

def eval_input_fn(features, labels=None):
    """定义评估函数，用于评估或预测。
    
    Parameters
    -----
    features : 类数组类型。 形状：[样本数量， 特征数量]
        用于测试的特征矩阵。
    labels : 类数组类型。形状为：[样本数量]
        每个样本对应的标签。（分类）
        
    Returns
    -----
    dataset : tf.data.Dataset
        数据集。
    """
    # 将特征转换成字典类型
    features = dict(features)
    # 如果要进行未知数据的预测，则没有标签。
    if labels is None:
        inputs = features
    else:
        inputs = (features, labels)
    # 创建数据集
    dataset = tf.data.Dataset.from_tensor_slices(inputs)
    # 每次取出100条记录
    dataset = dataset.batch(100)
    return dataset

X, y = load_data(r"data.csv")
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.25, random_state=0)

# 定义特征列列表
my_feature_columns = []

for key in train_X.keys():
    # 创建tensorflow特征列，并加入到特征列表当中。
    my_feature_columns.append(tf.feature_column.numeric_column(key=key))

classifier = tf.estimator.DNNClassifier(feature_columns=my_feature_columns, hidden_units=[512] * 2, n_classes=10, optimizer="SGD")
classifier.train(input_fn=lambda : train_input_fn(train_X, train_y))
classifier.evaluate(input_fn=lambda : eval_input_fn(test_X, test_y))
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ADMINI~1\AppData\Local\Temp\tmpxm0oj0jp
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\ADMINI~1\\AppData\\Local\\Temp\\tmpxm0oj0jp', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000000000EE57748>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ADMINI~1\AppData\Local\Temp\tmpxm0oj0jp\model.ckpt.
# INFO:tensorflow:loss = 121.42422, step = 1
# INFO:tensorflow:global_step/sec: 55.3372
# INFO:tensorflow:loss = 46.553265, step = 101 (1.809 sec)
# INFO:tensorflow:global_step/sec: 72.776
# INFO:tensorflow:loss = 50.102554, step = 201 (1.375 sec)
# INFO:tensorflow:global_step/sec: 79.2976
# INFO:tensorflow:loss = 46.348114, step = 301 (1.261 sec)
# INFO:tensorflow:global_step/sec: 56.7182
# INFO:tensorflow:loss = 51.20833, step = 401 (1.761 sec)
# INFO:tensorflow:global_step/sec: 76.2733
# INFO:tensorflow:loss = 49.07821, step = 501 (1.311 sec)
# INFO:tensorflow:global_step/sec: 74.4005
# INFO:tensorflow:loss = 52.36456, step = 601 (1.342 sec)
# INFO:tensorflow:global_step/sec: 87.3313
# INFO:tensorflow:loss = 46.241627, step = 701 (1.146 sec)
# INFO:tensorflow:global_step/sec: 59.9486
# INFO:tensorflow:loss = 44.929695, step = 801 (1.669 sec)
# INFO:tensorflow:global_step/sec: 71.2718
# INFO:tensorflow:loss = 47.95266, step = 901 (1.403 sec)
# INFO:tensorflow:global_step/sec: 82.8453
# INFO:tensorflow:loss = 38.471245, step = 1001 (1.208 sec)
# INFO:tensorflow:global_step/sec: 85.6849
