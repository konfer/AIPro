# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import norm

# %%
normalArr = np.random.normal(0, 1, 10000)

# %%
plt.plot(normalArr)

# %%
normalArr
# Out:
# array([-1.27318264e+00,  7.34483619e-01,  8.91637689e-01,  1.23259643e+00,
#        -1.26762335e-01,  7.66111976e-01,  6.23524473e-01,  1.05775441e+00,
#         4.18612463e-04, -1.26090171e-01,  8.83046779e-01, -4.20483798e-01,
#        -1.70032140e+00,  1.35504964e-01,  2.32711792e+00, -3.10037689e-01,
#        -8.88903273e-01,  1.31346696e+00,  1.20639276e+00, -4.92058831e-01,
#         1.41411675e+00,  1.17470086e-01,  6.95026398e-01,  1.19141823e+00,
#        -3.21004700e-01, -1.21569008e-01,  1.05679927e+00, -8.38755517e-01,
#        -2.12163990e+00,  3.94205710e-01,  7.30989189e-01, -6.22309632e-01,
#         2.46351954e-01,  5.18677128e-01, -1.33001067e+00,  2.15882747e-01,
#         1.59727540e+00,  3.33764811e-02, -1.09290644e+00, -3.78629244e-01])

# %%
yArr = stats.norm.pdf(np.linspace(-4, 4, 100))

# %%
yArr
# Out:
# array([1.33830226e-04, 1.84295302e-04, 2.52138056e-04, 3.42709873e-04,
#        4.62784614e-04, 6.20862299e-04, 8.27514755e-04, 1.09577221e-03,
#        1.44154732e-03, 1.88408981e-03, 2.44646147e-03, 3.15601632e-03,
#        4.04486639e-03, 5.15030799e-03, 6.51517825e-03, 8.18810653e-03,
#        1.02236211e-02, 1.26820683e-02, 1.56292995e-02, 1.91360817e-02,
#        2.32771927e-02, 2.81301641e-02, 3.37736510e-02, 4.02854146e-02,
#        4.77399263e-02, 5.62056185e-02, 6.57418315e-02, 7.63955298e-02,
#        8.81978860e-02, 1.01160853e-01, 1.15273870e-01, 1.30500851e-01,
#        1.46777638e-01, 1.64010075e-01, 1.82072870e-01, 2.00809396e-01,
#        2.20032535e-01, 2.39526659e-01, 2.59050772e-01, 2.78342808e-01,
#        2.97125003e-01, 3.15110210e-01, 3.32008980e-01, 3.47537175e-01,
#        3.61423830e-01, 3.73418974e-01, 3.83301094e-01, 3.90883931e-01,
#        3.96022313e-01, 3.98616779e-01, 3.98616779e-01, 3.96022313e-01,
# ...

# %%
plt.plot(np.linspace(-4, 4, 100),
           yArr, )

# %%
plt.hist(normalArr, bins = 200, normed=True)
plt.show()

# %%
normalArrFromNorm = norm.rvs(loc = 0, scale = 1, size = 10000)

# %%
plt.hist(normalArrFromNorm, bins = 200, normed=True)
plt.show()

# %%
binomArr = np.arange(20)

# %%
stats.binom.pmf(1, p =0.5, n =3)
# Out:
# 0.375

# %%
stats.binom.cdf(0, p =0.5, n =3)
# Out:
# 0.125

# %%
stats.poisson.pmf(0, 3.4)
# Out:
# 0.03337326996032608

# %%
stats.poisson.pmf(0, 6)
# Out:
# 0.0024787521766663585

# %%
stats.uniform.pdf(10, 30)
# Out:
# 0.0

# %%
help(stats.uniform.pdf)
# Out:
# Help on method pdf in module scipy.stats._distn_infrastructure:
#
# pdf(x, *args, **kwds) method of scipy.stats._continuous_distns.uniform_gen instance
#     Probability density function at x of the given RV.
#
#     Parameters
#     ----------
#     x : array_like
#         quantiles
#     arg1, arg2, arg3,... : array_like
#         The shape parameter(s) for the distribution (see docstring of the
#         instance object for more information)
#     loc : array_like, optional
#         location parameter (default=0)
#     scale : array_like, optional
#         scale parameter (default=1)
#
#     Returns
#     -------
#     pdf : ndarray
#         Probability density function evaluated at x
