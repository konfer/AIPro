# %%
import pandas as pd
import numpy as np

# %%
arr = np.array([[1,2,3],[4,5,6]])

# %%
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
randomArr=np.random.random((2,3))

# %%
randomArr
# Out:
# array([[0.23407338, 0.83042785, 0.41360038],
#        [0.39643164, 0.6679337 , 0.0553473 ]])

# %%
print(arr.shape,arr.dtype,randomArr.shape,randomArr.dtype)
# Out:
# (2, 3) int64 (2, 3) float64

# %%
arr = arr.astype(np.float)

# %%
arr
# Out:
# array([[1., 2., 3.],
#        [4., 5., 6.]])

# %%
print(arr.dtype)
# Out:
# float64

# %%
print(arr[1,2])
# Out:
# 6.0

# %%
print(arr[:,2])
# Out:
# [3. 6.]

# %%
print(arr[:,1])
# Out:
# [2. 5.]

# %%
arr.size
# Out:
# 6

# %%
arr.itemsize
# Out:
# 8

# %%
arr.shape
# Out:
# (2, 3)

# %%
arr > 2
# Out:
# array([[False, False,  True],
#        [ True,  True,  True]])

# %%
boolArr = arr[arr>2]

# %%
boolArr
# Out:
# array([3., 4., 5., 6.])

# %%
boolArr*2
# Out:
# array([ 6.,  8., 10., 12.])

# %%
boolArr
# Out:
# array([3., 4., 5., 6.])

# %%
boolArr=boolArr*2

# %%
arr+randomArr
# Out:
# array([[1.23407338, 2.83042785, 3.41360038],
#        [4.39643164, 5.6679337 , 6.0553473 ]])

# %%
arr-randomArr
# Out:
# array([[0.76592662, 1.16957215, 2.58639962],
#        [3.60356836, 4.3320663 , 5.9446527 ]])

# %%
arr*randomArr
# Out:
# array([[0.23407338, 1.6608557 , 1.24080113],
#        [1.58572656, 3.33966852, 0.33208377]])

# %%
randomArr/arr
# Out:
# array([[0.23407338, 0.41521393, 0.13786679],
#        [0.09910791, 0.13358674, 0.00922455]])

# %%
arr
# Out:
# array([[1., 2., 3.],
#        [4., 5., 6.]])

# %%
randomArr
# Out:
# array([[0.23407338, 0.83042785, 0.41360038],
#        [0.39643164, 0.6679337 , 0.0553473 ]])

# %% [markdown]
# ## BroadCast

# %%
arr+2
# Out:
# array([[3., 4., 5.],
#        [6., 7., 8.]])

# %%
a=np.random.random((8,1,6,1))
b=np.random.random((2,7,1,5))

# %%
c=np.random.random((1,1,6,1))
d=np.random.random((2,7,1,5))

# %%
c+d
# Out:
# array([[[[1.404997  , 1.09404249, 0.65478479, 0.67270937, 0.85504053],
#          [1.25467315, 0.94371864, 0.50446094, 0.52238553, 0.70471668],
#          [0.91740549, 0.60645098, 0.16719328, 0.18511786, 0.36744901],
#          [1.45844864, 1.14749413, 0.70823643, 0.72616101, 0.90849217],
#          [1.71576086, 1.40480635, 0.96554865, 0.98347323, 1.16580439],
#          [1.46888568, 1.15793118, 0.71867348, 0.73659806, 0.91892921]],
#
#         [[1.50422702, 1.4964333 , 0.61526824, 1.3416049 , 1.16490697],
#          [1.35390317, 1.34610946, 0.4649444 , 1.19128105, 1.01458312],
#          [1.01663551, 1.00884179, 0.12767673, 0.85401338, 0.67731546],
#          [1.55767866, 1.54988494, 0.66871988, 1.39505654, 1.21835861],
#          [1.81499088, 1.80719716, 0.9260321 , 1.65236875, 1.47567083],
#          [1.56811571, 1.56032199, 0.67915693, 1.40549358, 1.22879566]],
#
#         [[1.44035379, 1.32599273, 1.23415371, 1.44498148, 1.21799793],
# ...

# %%
e=np.arange(8).reshape(2,4)

# %%
e
# Out:
# array([[0, 1, 2, 3],
#        [4, 5, 6, 7]])

# %%
np.sum(e)
# Out:
# 28

# %%
np.sum(e)
# Out:
# 28

# %%
np.sum(e,axis=0)
# Out:
# array([ 4,  6,  8, 10])

# %%
np.sum(e,axis=1)
# Out:
# array([ 6, 22])

# %%
f=np.random.random((2,2))

# %%
np.dot(f,e)
# Out:
# array([[3.05915948, 4.12032426, 5.18148904, 6.24265383],
#        [1.06061444, 1.46972642, 1.8788384 , 2.28795038]])

# %% [markdown]
# ## Pandas dataStructure Series

# %%
pd.__version__
# Out:
# '0.22.0'

# %%
s = pd.Series([1,2,43,5])

# %%
s
# Out:
# 0     1
# 1     2
# 2    43
# 3     5
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s1=pd.Series([1,2,"Beijing",5,1231,-231,"konfer"])

# %%
s1
# Out:
# 0          1
# 1          2
# 2    Beijing
# 3          5
# 4       1231
# 5       -231
# 6     konfer
# dtype: object

# %%
s1=pd.Series([1,2,"Beijing",5,1231,-231,"konfer"],
                  index = [
                     '1', '2', '3', '4', '5' ,'6', '7'
                  ])

# %%
s1
# Out:
# 1          1
# 2          2
# 3    Beijing
# 4          5
# 5       1231
# 6       -231
# 7     konfer
# dtype: object

# %%
cities = {'Beijing': 55000, 'Shanghai': 60000, 'Shenzhen': 50000, 'Hangzhou': 20000, 'Guangzhou': 25000, 'Suzhou': None}
apts = pd.Series(cities,name="apt price")

# %%
apts
# Out:
# Beijing      55000.0
# Guangzhou    25000.0
# Hangzhou     20000.0
# Shanghai     60000.0
# Shenzhen     50000.0
# Suzhou           NaN
# Name: apt price, dtype: float64

# %%
s2 = pd.Series(np.random.random((5)), index=list("abcde"))

# %%
s2
# Out:
# a    0.803020
# b    0.950479
# c    0.352241
# d    0.592622
# e    0.560970
# dtype: float64

# %%
apts[[4,3,2]]
# Out:
# Shenzhen    50000.0
# Shanghai    60000.0
# Hangzhou    20000.0
# Name: apt price, dtype: float64

# %%
apts[:1]
# Out:
# Beijing    55000.0
# Name: apt price, dtype: float64

# %%
apts[0]
# Out:
# 55000.0

# %%
apts[0:]
# Out:
# Beijing      55000.0
# Guangzhou    25000.0
# Hangzhou     20000.0
# Shanghai     60000.0
# Shenzhen     50000.0
# Suzhou           NaN
# Name: apt price, dtype: float64

# %%
"Hangzhou" in apts
# Out:
# True

# %%
"liuzhou" in apts
# Out:
# False

# %%
apts.get("HangZhou",0)
# Out:
# 0

# %%
apts.get("Hangzhou",0)
# Out:
# 20000.0

# %%
apts < 50000
# Out:
# Beijing      False
# Guangzhou     True
# Hangzhou      True
# Shanghai     False
# Shenzhen     False
# Suzhou       False
# Name: apt price, dtype: bool

# %%
apts[apts < 50000]
# Out:
# Guangzhou    25000.0
# Hangzhou     20000.0
# Name: apt price, dtype: float64

# %%
apts[apts<apts.median()]
# Out:
# Guangzhou    25000.0
# Hangzhou     20000.0
# Name: apt price, dtype: float64

# %%
apts["Hangzhou"] = 20000

# %%
apts
# Out:
# Beijing      55000.0
# Guangzhou    25000.0
# Hangzhou     20000.0
# Shanghai     60000.0
# Shenzhen     50000.0
# Suzhou           NaN
# Name: apt price, dtype: float64

# %%
apts ** 2
# Out:
# Beijing      3.025000e+09
# Guangzhou    6.250000e+08
# Hangzhou     4.000000e+08
# Shanghai     3.600000e+09
# Shenzhen     2.500000e+09
# Suzhou                NaN
# Name: apt price, dtype: float64

# %%
np.square(apts)
# Out:
# Beijing      3.025000e+09
# Guangzhou    6.250000e+08
# Hangzhou     4.000000e+08
# Shanghai     3.600000e+09
# Shenzhen     2.500000e+09
# Suzhou                NaN
# Name: apt price, dtype: float64

# %%
np.sqrt(apts)
# Out:
# Beijing      234.520788
# Guangzhou    158.113883
# Hangzhou     141.421356
# Shanghai     244.948974
# Shenzhen     223.606798
# Suzhou              NaN
# Name: apt price, dtype: float64

# %%
data = {'city': ['Beijing', 'Shanghai', 'Guangzhou', 'Shenzhen', 'Hangzhou', 'Chongqing'],
       'year': [2016,2017,2016,2017,2016, 2016],
       'population': [2100, 2300, 1000, 700, 500, 500]}
pd.DataFrame(data)
# Out:
#         city  population  year
# 0    Beijing        2100  2016
# 1   Shanghai        2300  2017
# 2  Guangzhou        1000  2016
# 3   Shenzhen         700  2017
# 4   Hangzhou         500  2016
# 5  Chongqing         500  2016

# %%
f=pd.DataFrame(data,columns=["city","population","year"],
                index=["one","two","three","four","five","six"])

# %%
f.columns
# Out:
# Index(['city', 'population', 'year'], dtype='object')

# %%
f.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')

# %%
cars= {'Beijing': 55000, 'Shanghai': 60000, 'Shenzhen': 50000, 'Hangzhou': 20000, 'Guangzhou': 25000, 'Suzhou': None}

# %%
df=pd.DataFrame({"apts":apts,"cars":cars})

# %%
df
# Out:
#               apts     cars
# Beijing    55000.0  55000.0
# Guangzhou  25000.0  25000.0
# Hangzhou   20000.0  20000.0
# Shanghai   60000.0  60000.0
# Shenzhen   50000.0  50000.0
# Suzhou         NaN      NaN

# %%
dataOne= [{"July": 999999, "Han": 50000, "Zewei": 1000}, {"July": 99999, "Han": 8000, "Zewei": 200}]

# %%
dataOne
# Out:
# [{'Han': 50000, 'July': 999999, 'Zewei': 1000},
#  {'Han': 8000, 'July': 99999, 'Zewei': 200}]

# %%
dataOneDf=pd.DataFrame(dataOne,index=["salary","bonus"])

# %%
dataOneDf
# Out:
#           Han    July  Zewei
# salary  50000  999999   1000
# bonus    8000   99999    200

# %%
df
# Out:
#               apts     cars
# Beijing    55000.0  55000.0
# Guangzhou  25000.0  25000.0
# Hangzhou   20000.0  20000.0
# Shanghai   60000.0  60000.0
# Shenzhen   50000.0  50000.0
# Suzhou         NaN      NaN

# %%
df["total_cost"]=df["apts"]*70+df["cars"]

# %%
df
# Out:
#               apts     cars  total_cost
# Beijing    55000.0  55000.0   3905000.0
# Guangzhou  25000.0  25000.0   1775000.0
# Hangzhou   20000.0  20000.0   1420000.0
# Shanghai   60000.0  60000.0   4260000.0
# Shenzhen   50000.0  50000.0   3550000.0
# Suzhou         NaN      NaN         NaN

# %%
df.loc["Beijing"]
# Out:
# apts            55000.0
# cars            55000.0
# total_cost    3905000.0
# Name: Beijing, dtype: float64

# %%
df.iloc[1:3,0:2]
# Out:
#               apts     cars
# Guangzhou  25000.0  25000.0
# Hangzhou   20000.0  20000.0

# %%
f["population"]["four"]
# Out:
# 700

# %%
f
# Out:
#             city  population  year
# one      Beijing        2100  2016
# two     Shanghai        2300  2017
# three  Guangzhou        1000  2016
# four    Shenzhen         700  2017
# five    Hangzhou         500  2016
# six    Chongqing         500  2016

# %%
f["population"]["four"]=750
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
f
# Out:
#             city  population  year
# one      Beijing        2100  2016
# two     Shanghai        2300  2017
# three  Guangzhou        1000  2016
# four    Shenzhen         750  2017
# five    Hangzhou         500  2016
# six    Chongqing         500  2016

# %%
f.loc["four","population"] = 760

# %%
f
# Out:
#             city  population  year
# one      Beijing        2100  2016
# two     Shanghai        2300  2017
# three  Guangzhou        1000  2016
# four    Shenzhen         760  2017
# five    Hangzhou         500  2016
# six    Chongqing         500  2016

# %%
f.at["four","population"] =770

# %%
f
# Out:
#             city  population  year
# one      Beijing        2100  2016
# two     Shanghai        2300  2017
# three  Guangzhou        1000  2016
# four    Shenzhen         770  2017
# five    Hangzhou         500  2016
# six    Chongqing         500  2016

# %%
f.loc["four":"six","population"] = 770

# %%
f
# Out:
#             city  population  year
# one      Beijing        2100  2016
# two     Shanghai        2300  2017
# three  Guangzhou        1000  2016
# four    Shenzhen         770  2017
# five    Hangzhou         770  2016
# six    Chongqing         770  2016

# %%
f.at["four":"six","population"] = 780

# %%
f
# Out:
#             city  population  year
# one      Beijing        2100  2016
# two     Shanghai        2300  2017
# three  Guangzhou        1000  2016
# four    Shenzhen         780  2017
# five    Hangzhou         780  2016
# six    Chongqing         780  2016

# %%
f["debt"]=10000

# %%
f
# Out:
#             city  population  year   debt
# one      Beijing        2100  2016  10000
# two     Shanghai        2300  2017  10000
# three  Guangzhou        1000  2016  10000
# four    Shenzhen         780  2017  10000
# five    Hangzhou         780  2016  10000
# six    Chongqing         780  2016  10000

# %%
f.loc["six"] = 0

# %%
f
# Out:
#             city  population  year   debt
# one      Beijing        2100  2016  10000
# two     Shanghai        2300  2017  10000
# three  Guangzhou        1000  2016  10000
# four    Shenzhen         780  2017  10000
# five    Hangzhou         780  2016  10000
# six            0           0     0      0

# %%
f.loc[:,"debt"] = 10020

# %%
f
# Out:
#             city  population  year   debt
# one      Beijing        2100  2016  10020
# two     Shanghai        2300  2017  10020
# three  Guangzhou        1000  2016  10020
# four    Shenzhen         780  2017  10020
# five    Hangzhou         780  2016  10020
# six            0           0     0  10020

# %%
f.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')

# %%
f.columns
# Out:
# Index(['city', 'population', 'year', 'debt'], dtype='object')

# %%
f.debt=np.arange(6)*10000

# %%
f
# Out:
#             city  population  year   debt
# one      Beijing        2100  2016      0
# two     Shanghai        2300  2017  10000
# three  Guangzhou        1000  2016  20000
# four    Shenzhen         780  2017  30000
# five    Hangzhou         780  2016  40000
# six            0           0     0  50000

# %%
val = pd.Series([102192819,28193291,123123,3213211],
               index=f.columns)

# %%
val
# Out:
# city          102192819
# population     28193291
# year             123123
# debt            3213211
# dtype: int64

# %%
f.loc["six"] = val

# %%
f
# Out:
#             city  population    year     debt
# one      Beijing        2100    2016        0
# two     Shanghai        2300    2017    10000
# three  Guangzhou        1000    2016    20000
# four    Shenzhen         780    2017    30000
# five    Hangzhou         780    2016    40000
# six    102192819    28193291  123123  3213211

# %%
indexVal = pd.Series([102192819,28193291,123123],
                    index=["one","three","six"])

# %%
f.debt=indexVal

# %%
f
# Out:
#             city  population    year         debt
# one      Beijing        2100    2016  102192819.0
# two     Shanghai        2300    2017          NaN
# three  Guangzhou        1000    2016   28193291.0
# four    Shenzhen         780    2017          NaN
# five    Hangzhou         780    2016          NaN
# six    102192819    28193291  123123     123123.0

# %%
f["city"]["six"] = "Chongqing"
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
f
# Out:
#             city  population    year         debt
# one      Beijing        2100    2016  102192819.0
# two     Shanghai        2300    2017          NaN
# three  Guangzhou        1000    2016   28193291.0
# four    Shenzhen         780    2017          NaN
# five    Hangzhou         780    2016          NaN
# six    Chongqing    28193291  123123     123123.0

# %%
f["western"] = (f.city == "Chongqing")

# %%
f
# Out:
#             city  population    year         debt  western
# one      Beijing        2100    2016  102192819.0    False
# two     Shanghai        2300    2017          NaN    False
# three  Guangzhou        1000    2016   28193291.0    False
# four    Shenzhen         780    2017          NaN    False
# five    Hangzhou         780    2016          NaN    False
# six    Chongqing    28193291  123123     123123.0     True

# %%
f.T
# Out:
#                     one       two        three      four      five        six
# city            Beijing  Shanghai    Guangzhou  Shenzhen  Hangzhou  Chongqing
# population         2100      2300         1000       780       780   28193291
# year               2016      2017         2016      2017      2016     123123
# debt        1.02193e+08       NaN  2.81933e+07       NaN       NaN     123123
# western           False     False        False     False     False       True

# %%
f.index.name="index"

# %%
f.columns.name = "information"

# %%
f
# Out:
# information       city  population    year         debt  western
# index
# one            Beijing        2100    2016  102192819.0    False
# two           Shanghai        2300    2017          NaN    False
# three        Guangzhou        1000    2016   28193291.0    False
# four          Shenzhen         780    2017          NaN    False
# five          Hangzhou         780    2016          NaN    False
# six          Chongqing    28193291  123123     123123.0     True

# %%
pkFile = pd.read_csv("Pokemon.csv")

# %%
pkFile.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pkFile.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
pkFile.isnull()
# Out:
#          #   Name  Type 1  Type 2  Total     HP  Attack  Defense  Sp. Atk  \
# 0    False  False   False   False  False  False   False    False    False
# 1    False  False   False   False  False  False   False    False    False
# 2    False  False   False   False  False  False   False    False    False
# 3    False  False   False   False  False  False   False    False    False
# 4    False  False   False    True  False  False   False    False    False
# 5    False  False   False    True  False  False   False    False    False
# 6    False  False   False   False  False  False   False    False    False
# 7    False  False   False   False  False  False   False    False    False
# 8    False  False   False   False  False  False   False    False    False
# 9    False  False   False    True  False  False   False    False    False
# 10   False  False   False    True  False  False   False    False    False
# 11   False  False   False    True  False  False   False    False    False
# ...

# %%
pkFile.isnull().any()
# Out:
# #             False
# Name          False
# Type 1        False
# Type 2         True
# Total         False
# HP            False
# Attack        False
# Defense       False
# Sp. Atk       False
# Sp. Def       False
# Speed         False
# Generation    False
# Legendary     False
# dtype: bool

# %%
pkFile["Type 2"]
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 4         NaN
# 5         NaN
# 6      Flying
# 7      Dragon
# 8      Flying
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15     Flying
# 16     Poison
# 17     Poison
# 18     Poison
# 19     Poison
# 20     Flying
# 21     Flying
# 22     Flying
# 23     Flying
# 24        NaN
# 25        NaN
# 26     Flying
# 27     Flying
# 28        NaN
# 29        NaN
#         ...
# 770       NaN
# 771    Flying
# 772     Fairy
# 773     Fairy
# 774       NaN
# 775       NaN
# 776       NaN
# 777     Fairy
# 778     Grass
# 779     Grass
# 780     Grass
# 781     Grass
# 782     Grass
# 783     Grass
# 784     Grass
# 785     Grass
# 786     Grass
# 787     Grass
# 788       NaN
# 789       NaN
# 790    Dragon
# 791    Dragon
# 792       NaN
# 793    Flying
# 794    Ground
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# ...

# %%
pkFile["Type 2"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5       True
# 6      False
# 7      False
# 8      False
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24      True
# 25      True
# 26     False
# 27     False
# 28      True
# 29      True
#        ...
# 770     True
# 771    False
# 772    False
# 773    False
# 774     True
# 775     True
# 776     True
# 777    False
# 778    False
# 779    False
# 780    False
# 781    False
# 782    False
# 783    False
# 784    False
# 785    False
# 786    False
# 787    False
# 788     True
# 789     True
# 790    False
# 791    False
# 792     True
# 793    False
# 794    False
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Type 2, Length: 800, dtype: bool

# %%
pkFile.loc[pkFile["Type 2"].isnull()]
# Out:
#        #                     Name    Type 1 Type 2  Total   HP  Attack  \
# 4      4               Charmander      Fire    NaN    309   39      52
# 5      5               Charmeleon      Fire    NaN    405   58      64
# 9      7                 Squirtle     Water    NaN    314   44      48
# 10     8                Wartortle     Water    NaN    405   59      63
# 11     9                Blastoise     Water    NaN    530   79      83
# 12     9  BlastoiseMega Blastoise     Water    NaN    630   79     103
# 13    10                 Caterpie       Bug    NaN    195   45      30
# 14    11                  Metapod       Bug    NaN    205   50      20
# 24    19                  Rattata    Normal    NaN    253   30      56
# 25    20                 Raticate    Normal    NaN    413   55      81
# 28    23                    Ekans    Poison    NaN    288   35      60
# 29    24                    Arbok    Poison    NaN    438   60      85
# ...

# %%
pkFile.loc[pkFile["Type 2"].isnull(), "Type 2"]
# Out:
# 4      NaN
# 5      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 24     NaN
# 25     NaN
# 28     NaN
# 29     NaN
# 30     NaN
# 31     NaN
# 32     NaN
# 33     NaN
# 34     NaN
# 35     NaN
# 37     NaN
# 38     NaN
# 40     NaN
# 41     NaN
# 42     NaN
# 43     NaN
# 55     NaN
# 56     NaN
# 57     NaN
# 58     NaN
# 59     NaN
# 60     NaN
#       ...
# 721    NaN
# 722    NaN
# 724    NaN
# 725    NaN
# 727    NaN
# 732    NaN
# 733    NaN
# 737    NaN
# 738    NaN
# 739    NaN
# 740    NaN
# 741    NaN
# 742    NaN
# 744    NaN
# 745    NaN
# 746    NaN
# 747    NaN
# 752    NaN
# 753    NaN
# 754    NaN
# 755    NaN
# 762    NaN
# 763    NaN
# 770    NaN
# 774    NaN
# 775    NaN
# 776    NaN
# 788    NaN
# 789    NaN
# 792    NaN
# Name: Type 2, Length: 386, dtype: object

# %%
pkFile.loc[pkFile["Type 2"].isnull(), "Type 2"] = pkFile.loc[pkFile["Type 2"].isnull(), "Type 1"]

# %%
pkFile
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire    Fire    309   39      52
# 5      5                 Charmeleon      Fire    Fire    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water   Water    314   44      48
# 10     8                  Wartortle     Water   Water    405   59      63
# 11     9                  Blastoise     Water   Water    530   79      83
# ...

# %%
pkFile.isnull()
# Out:
#          #   Name  Type 1  Type 2  Total     HP  Attack  Defense  Sp. Atk  \
# 0    False  False   False   False  False  False   False    False    False
# 1    False  False   False   False  False  False   False    False    False
# 2    False  False   False   False  False  False   False    False    False
# 3    False  False   False   False  False  False   False    False    False
# 4    False  False   False   False  False  False   False    False    False
# 5    False  False   False   False  False  False   False    False    False
# 6    False  False   False   False  False  False   False    False    False
# 7    False  False   False   False  False  False   False    False    False
# 8    False  False   False   False  False  False   False    False    False
# 9    False  False   False   False  False  False   False    False    False
# 10   False  False   False   False  False  False   False    False    False
# 11   False  False   False   False  False  False   False    False    False
# ...

# %%
apts.notnull()
# Out:
# Beijing       True
# Guangzhou     True
# Hangzhou      True
# Shanghai      True
# Shenzhen      True
# Suzhou       False
# Name: apt price, dtype: bool

# %%
apts
# Out:
# Beijing      55000.0
# Guangzhou    25000.0
# Hangzhou     20000.0
# Shanghai     60000.0
# Shenzhen     50000.0
# Suzhou           NaN
# Name: apt price, dtype: float64

# %%
apts.isnull()
# Out:
# Beijing      False
# Guangzhou    False
# Hangzhou     False
# Shanghai     False
# Shenzhen     False
# Suzhou        True
# Name: apt price, dtype: bool

# %%
f.to_csv("MySample.csv")

# %%
obj = pd.Series(range(4),index = list("abcd"))

# %%
obj
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64

# %%
index = obj.index

# %%
index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
index[1:-1]
# Out:
# Index(['b', 'c'], dtype='object')

# %%
obj["d"]
# Out:
# 3

# %%
obj[["b","d"]]
# Out:
# b    1
# d    3
# dtype: int64

# %%
myObj = pd.Series([4.5, 7.2 ,-4.2 , 3.2 ], index=['d', 'b', 'a' ,'c'])

# %%
myObj
# Out:
# d    4.5
# b    7.2
# a   -4.2
# c    3.2
# dtype: float64

# %%
myObj.reindex(list("abcd"))
# Out:
# a   -4.2
# b    7.2
# c    3.2
# d    4.5
# dtype: float64

# %%
myObj.reindex(list("abcde"))
# Out:
# a   -4.2
# b    7.2
# c    3.2
# d    4.5
# e    NaN
# dtype: float64

# %%
myObj
# Out:
# d    4.5
# b    7.2
# a   -4.2
# c    3.2
# dtype: float64

# %%
obj3 = pd.Series(["blue","yellow","red"], index=[0,2,4])

# %%
obj3
# Out:
# 0      blue
# 2    yellow
# 4       red
# dtype: object

# %%
obj3.reindex(range(6), method="ffill")
# Out:
# 0      blue
# 1      blue
# 2    yellow
# 3    yellow
# 4       red
# 5       red
# dtype: object

# %%
obj3.reindex(range(6), method="bfill")
# Out:
# 0      blue
# 1    yellow
# 2    yellow
# 3       red
# 4       red
# 5       NaN
# dtype: object

# %%
f.reindex(index=["two","five"],
                  columns=["city","population"])
# Out:
# information      city  population
# index
# two          Shanghai        2300
# five         Hangzhou         780

# %%
f
# Out:
# information       city  population    year         debt  western
# index
# one            Beijing        2100    2016  102192819.0    False
# two           Shanghai        2300    2017          NaN    False
# three        Guangzhou        1000    2016   28193291.0    False
# four          Shenzhen         780    2017          NaN    False
# five          Hangzhou         780    2016          NaN    False
# six          Chongqing    28193291  123123     123123.0     True

# %%
obj3.drop(2)
# Out:
# 0    blue
# 4     red
# dtype: object

# %%
obj3
# Out:
# 0      blue
# 2    yellow
# 4       red
# dtype: object

# %%
obj3
# Out:
# 0      blue
# 2    yellow
# 4       red
# dtype: object

# %%
f.drop(["city","year"],axis=1)
# Out:
# information  population         debt  western
# index
# one                2100  102192819.0    False
# two                2300          NaN    False
# three              1000   28193291.0    False
# four                780          NaN    False
# five                780          NaN    False
# six            28193291     123123.0     True

# %%
goog = pd.read_csv("GOOG.csv")

# %%
goog.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2004-08-19  49.813286  51.835709  47.800831  49.982655  49.982655  44871300
# 1  2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942800
# 2  2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342800
# 3  2004-08-24  55.412300  55.591629  51.591621  52.239193  52.239193  15319700
# 4  2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086   9232100

# %%
goog = pd.read_csv("GOOG.csv", index_col="Date", parse_dates=["Date"])

# %%
goog
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2004-08-19   49.813286   51.835709   47.800831   49.982655   49.982655
# 2004-08-20   50.316402   54.336334   50.062355   53.952770   53.952770
# 2004-08-23   55.168217   56.528118   54.321388   54.495735   54.495735
# 2004-08-24   55.412300   55.591629   51.591621   52.239193   52.239193
# 2004-08-25   52.284027   53.798351   51.746044   52.802086   52.802086
# 2004-08-26   52.279045   53.773445   52.134586   53.753517   53.753517
# 2004-08-27   53.848164   54.107193   52.647663   52.876804   52.876804
# 2004-08-30   52.443428   52.548038   50.814533   50.814533   50.814533
# 2004-08-31   50.958992   51.661362   50.889256   50.993862   50.993862
# 2004-09-01   51.158245   51.292744   49.648903   49.937820   49.937820
# 2004-09-02   49.409801   50.993862   49.285267   50.565468   50.565468
# 2004-09-03   50.286514   50.680038   49.474556   49.818268   49.818268
# ...

# %%
# %matplotlib inline

# %%
goog["Adj Close"].plot()
